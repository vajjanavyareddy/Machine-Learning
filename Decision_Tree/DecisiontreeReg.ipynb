# %%
import numpy as np
import pandas as pd

# %%
X=np.array([50,120,180,250,320,380]).reshape(-1,1)
y = np.array([500,1000,1000,1800,2500,2500])

# %%
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor(max_depth=3,random_state=42)
dt_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
X_grid = np.linspace(0,400,200).reshape(-1,1)
y_pred = dt_reg.predict(X_grid)
import matplotlib.pyplot as plt
plt.scatter(X,y,color='red')
plt.plot(X_grid,y_pred,color='blue')
plt.title('Decision Tree Regression- Electricity Bill Slabs')
plt.xlabel('Units Consumed')
plt.ylabel('Electricity Bill')
plt.show()

# %%
units = float(input("Enter the units consumed: "))
bill = dt_reg.predict([[units]])
print(f"The electricity bill for {units} units is {bill[0]:.0f}")
# Out:
# Enter the units consumed: 50
# The electricity bill for 50.0 units is 500

# %% [markdown]
# Example 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

X1= np.array([1,2,3,4,5,6,7,8]).reshape(-1,1)
y1= np.array([3,3.5,4,4.2,6,6.5,7,7.2])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X1,y1,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor(max_depth=3,random_state=42)
dt_reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
X_grid = np.linspace(0,8,100).reshape(-1,1)
y_pred = dt_reg.predict(X_grid)
plt.scatter(X1,y1,color='red')
plt.plot(X_grid,y_pred,color='blue')
plt.title('Decision Tree Regression')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
dt_deep = DecisionTreeRegressor(max_depth=None)
dt_deep.fit(X_train,y_train)
y_pred_deep = dt_deep.predict(X_grid)

plt.scatter(X1,y1)
plt.plot(X_grid,y_pred_deep,color='green')
plt.title('Overfitting Tree')

plt.show()

# %%
dt_controlled = DecisionTreeRegressor(max_depth=3)
dt_controlled.fit(X_train,y_train)
y_pred_controlled = dt_controlled.predict(X_grid)

plt.scatter(X1,y1)
plt.plot(X_grid,y_pred_controlled,color='orange')
plt.title('Controlled Tree')

plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_test_pred_deep = dt_deep.predict(X_test)
y_test_pred_controlled = dt_controlled.predict(X_test)
mse_deep = mean_squared_error(y_test,y_test_pred_deep)
mse_controlled = mean_squared_error(y_test,y_test_pred_controlled)
r2_deep = r2_score(y_test,y_test_pred_deep)
r2_controlled = r2_score(y_test,y_test_pred_controlled)
print(f"MSE for Deep Tree: {mse_deep:.2f}")
print(f"MSE for Controlled Tree: {mse_controlled:.2f}")
print(f"R2 Score for Deep Tree: {r2_deep:.2f}")
print(f"R2 Score for Controlled Tree: {r2_controlled:.2f}")
# Out:
# MSE for Deep Tree: 0.25
# MSE for Controlled Tree: 0.25
# R2 Score for Deep Tree: 0.89
# R2 Score for Controlled Tree: 0.89
