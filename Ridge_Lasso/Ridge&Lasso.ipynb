# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X= np.array([1,2,3,4,5,6]).reshape(-1,1)
y= np.array([35,40,50,60,65,70])

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lin_reg.predict(X_train)
y_test_pred = lin_reg.predict(X_test)

# %%
print("Good Fit (LR)")
print("Train MSE: ",mean_squared_error(y_train, y_train_pred))
print("Test MSE: ",mean_squared_error(y_test, y_test_pred))
print("Train R2: ",r2_score(y_train, y_train_pred))
print("Test R2: ",r2_score(y_test, y_test_pred))
# Out:
# Good Fit (LR)
# Train MSE:  1.875
# Test MSE:  18.625
# Train R2:  0.9657142857142857
# Test R2:  -1.98

# %%
plt.scatter(X,y)
plt.plot(X,lin_reg.predict(X),color='green')
plt.title('Good Fit: Marks vs Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %%
poly = PolynomialFeatures(degree=5)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

overfit_model = LinearRegression()
overfit_model.fit(X_train_poly, y_train)

y_train_pred_poly = overfit_model.predict(X_train_poly)
y_test_pred_poly = overfit_model.predict(X_test_poly)

# %%
print("Overfit (Poly)")
print("Train MSE: ",mean_squared_error(y_train, y_train_pred_poly))
print("Test MSE: ",mean_squared_error(y_test, y_test_pred_poly))
print("Train R2: ",r2_score(y_train, y_train_pred_poly))
print("Test R2: ",r2_score(y_test, y_test_pred_poly))
# Out:
# Overfit (Poly)
# Train MSE:  8.363894592162157e-24
# Test MSE:  17.88287912161181
# Train R2:  1.0
# Test R2:  -1.8612606594578898

# %%
plt.scatter(X,y)
plt.plot(X,overfit_model.predict(poly.fit_transform(X)),color='green')
plt.title('Overfit: Marks vs Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
# Out:
# Text(0, 0.5, 'Marks')

# %%
ploy = PolynomialFeatures(degree=5)
X_poly = poly.fit_transform(X)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1)
ridge.fit(X_poly,y)

y_ridge_pred = ridge.predict(X_poly)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("Ridge")
print("MSE: ",mean_squared_error(y, y_ridge_pred))
print("R2: ",r2_score(y, y_ridge_pred))
# Out:
# Ridge
# MSE:  0.24058058055628095
# R2:  0.9985320506949108

# %%
import matplotlib.pyplot as plt
X_grid = np.linspace(1,6,100).reshape(-1,1)
X_grid_poly = poly.fit_transform(X_grid)
plt.scatter(X,y)
plt.plot(X,ridge.predict(poly.fit_transform(X)),color='green')
plt.title('Ridge: Marks vs Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha =0.1)
lasso.fit(X_poly,y)
y_lasso_pred = lasso.predict(X_poly)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("Lasso")
print("MSE: ",mean_squared_error(y, y_lasso_pred))
print("R2: ",r2_score(y, y_lasso_pred))
# Out:
# Lasso
# MSE:  0.7727384155729786
# R2:  0.9952849859388767

# %%
print("Ridge")
print("MSE: ",mean_squared_error(y, y_ridge_pred))
print("R2: ",r2_score(y, y_ridge_pred))
print("Lasso")
print("MSE: ",mean_squared_error(y, y_lasso_pred))
print("R2: ",r2_score(y, y_lasso_pred))
# Out:
# Ridge
# MSE:  0.24058058055628095
# R2:  0.9985320506949108
# Lasso
# MSE:  0.7727384155729786
# R2:  0.9952849859388767

# %%
X_grid = np.linspace(1,6,100).reshape(-1,1)
X_grid_poly = poly.fit_transform(X_grid)
plt.scatter(X,y)
plt.plot(X,lasso.predict(poly.fit_transform(X)),color='green')
plt.title('Lasso: Marks vs Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
# Out:
# Text(0, 0.5, 'Marks')
